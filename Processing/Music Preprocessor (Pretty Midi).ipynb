# %%
# Music processing
from pretty_midi import *
# Algorithms
from itertools import takewhile
# File management
import os
from glob import glob
from pathlib import Path
import csv

# %% [markdown]
# ## Settings

# %%
# Classical music target and destination
corpus_path = 'C:\\Users\\alext\\Desktop\\School\\2021 Spring\\CS 271\\Final Project\\Feature Extraction\\Classical\\Classical Corpus'
export_path = 'C:\\Users\\alext\\Desktop\\School\\2021 Spring\\CS 271\\Final Project\\Feature Extraction\\Classical\\Classical Extracted Notes'

# Jazz music target and destination
#corpus_path = 'C:\\Users\\alext\\Desktop\\School\\2021 Spring\\CS 271\\Final Project\\Feature Extraction\\Jazz\\Jazz Corpus'
#export_path = 'C:\\Users\\alext\\Desktop\\School\\2021 Spring\\CS 271\\Final Project\\Feature Extraction\\Jazz\\Jazz Extracted Notes'

# Minimum number of notes per part
min_notes = 25
# Minimum number of chord phrases per part
min_chords = 1

# %% [markdown]
# ## Export a Music File to a CSV File

# %%
def export_file(corpus_path, export_path, file_name):
    # Construct the full path of the music file
    file_path = os.path.join(corpus_path, file_name);
    # Construct the full path of the target csv file
    target_path = os.path.join(export_path, file_name[:-4] + '.csv');
    
    # If the csv already exists, skip this music file
    if os.path.exists(target_path):
        return
    
    # Parse the file and convert it into a stream object
    midi_data = pretty_midi.PrettyMIDI(file_path)
    
    # The number of keyboard parts in the song
    keyboard_parts = 0
    
    # Iterate over all instrument parts in the score
    for inst in midi_data.instruments:
        # Get the class of instrument
        inst_class = program_to_instrument_class(inst.program)
        
        # Check for keyboard instruments
        if inst_class == 'Piano' or inst_class == 'Organ':
            # Check if the part meets the minimum note requirement
            if len(inst.notes) >= min_notes:
                keyboard_parts += 1
                
                # Remove the extension of the music file name
                part_name = file_name[:-4]

                # If this isn't the first keybaord part, append the part number to the part name
                if keyboard_parts > 1:
                    part_name += '-' + str(keyboard_parts)
                
                # Export the notes in the part to a csv
                export_part(corpus_path, export_path, inst.notes, part_name)

# %% [markdown]
# ## Export a Part to a CSV File

# %%
def export_part(corpus_path, export_path, part, part_name):
    # Extract the notes of the part
    notes = extract_notes(part)
    
    # If the part doesn't contain enough chords, don't export it
    if notes == None:
        return
    
    # Construct the full path of the target csv file
    csv_path = os.path.join(export_path, part_name + '.csv');
    
    # Write the features list to a csv file
    with open(csv_path, 'w', newline='') as csv_file:
        write = csv.writer(csv_file)
        write.writerows(notes)

# %% [markdown]
# ## Extract the Notes from a Part

# %%
def extract_notes(part):
    # An orderd list of phrases (notes and chords) in the song
    phrase_list = []
    # The phrase currently being processed
    phrase = []
    # The number of chords in the part
    num_chords = 0
    # The start time of the note currently being processed
    curr_time = part[0].start
    
    # Organize all notes into parts and add them to the part list
    for note in part:
        # If this note starts a the same time as the previous,
        # append it to the chord
        if note.start == curr_time:
            phrase.append(str(note.pitch))
        # If this note starts later than the previous one,
        # save the last phrase and construct a new one
        else:
            phrase_list.append(phrase)
            
            if len(phrase) > 1:
                num_chords += 1
            
            phrase = []
            phrase.append(str(note.pitch))
            curr_time = note.start
    
    # Add the last phrase
    phrase_list.append(phrase)
    
    if len(phrase) > 1:
        num_chords += 1
    
    # If the part doesn't contain enough chords, return nothing
    if num_chords < min_chords:
        return None
    
    return phrase_list

# %% [markdown]
# ## Preprocess the Music Corpus

# %%
print('Extracting...\n')

# Go to the corpus directory
os.chdir(corpus_path)

# Get a list of all music files in the corpus
music_files = glob('*.mid')

num_errors = 0

# Export the notes of each score as a csv file
for file_name in music_files:
    try:
        export_file(corpus_path, export_path, file_name)
    except Exception as err:
        print("Skipping File {0}. Error: {1}".format(file_name, err))
        num_errors += 1

print('\nFinished')
print('Total number of errors: ' + str(num_errors))
# Out:
# Extracting...
# C:\Users\alext\anaconda3\envs\DeepLearning\lib\site-packages\pretty_midi\pretty_midi.py:101: RuntimeWarning: Tempo, Key or Time signature change events found on non-zero tracks.  This is not a valid type 0 or type 1 MIDI file.  Tempo, Key or Time Signature may be wrong.
#   RuntimeWarning)
# Skipping File 2iH24VcccnNwNGDxaxE5Lu.mid. Error: running status without last_status
# Skipping File 2uEVCciTszWz9oBCZEkHo7.mid. Error: running status without last_status
# Skipping File 2vFiGbBPxaMw4YKiahe6Sp.mid. Error: data byte must be in range 0..127
# Skipping File 3FbGdmJA9pmnPFz6wbSAvX.mid. Error: running status without last_status
# Skipping File 3SzeJqBupEcw3RWqrXnqXH.mid. Error: running status without last_status
# Skipping File 3Yvn47uez2jRGYzYTo9Pp7.mid. Error: running status without last_status
# Skipping File 42FzccnPgQpu784FNh2bZj.mid. Error: data byte must be in range 0..127
# Skipping File 43KktYzTPQZR4ZMrkRRtF8.mid. Error: running status without last_status
# Skipping File 4fA6vXybyrcxLB7P7WpEbn.mid. Error: running status without last_status
# Skipping File 58zz5WUjxtedjRTNZddkpc.mid. Error: running status without last_status
# Skipping File 5LoRn3ewHA96JhLRkHXKvn.mid. Error: data byte must be in range 0..127
# Skipping File 5PuxGev8NZeyscYJXaf8fn.mid. Error: running status without last_status
# Skipping File 6apaNjLFDNcW3Fiv7Hd4Wh.mid. Error: running status without last_status
# Skipping File 6dpe26vKvm6fBCpEFEZv8k.mid. Error: MIDI file has a largest tick of 4295154736, it is likely corrupt
# Skipping File 6dzjJkTLyoHvyciAi8L6BQ.mid. Error: running status without last_status
# Skipping File 76VBUH37fhLCoU3rrnRERy.mid. Error: running status without last_status
# Skipping File 7GhSpWspKE7AJjQh43Tv8H.mid. Error: running status without last_status
# Skipping File 7xDxRpEmbxUwbmgt62yzfr.mid. Error: running status without last_status
# Skipping File 8KQ7gw7YNJCLo99ceQkUVJ.mid. Error: running status without last_status
# Skipping File 8X8G8n2cyHjdmEUez439VV.mid. Error: running status without last_status
# Skipping File 8yhiiuo6geN7WQ63hjRbAX.mid. Error: running status without last_status
# Skipping File AEEnPgoprwEdsefGYeX2So.mid. Error: data byte must be in range 0..127
# Skipping File af6bSm3q46B7uUDiFKHm9o.mid. Error: data byte must be in range 0..127
# Skipping File B4xmPgj9JVphrH6HToMqA7.mid. Error: running status without last_status
# Skipping File bHseWoZ3yx2yu2zv7qb268.mid. Error: running status without last_status
# Skipping File BRVnqb9TtCjkw4wA9gijAA.mid. Error: running status without last_status
# Skipping File Bs8qnGkDkKrbSgU8b3GQT2.mid. Error: running status without last_status
# Skipping File BXoAMrwaBQW7sJPUSCgf2q.mid. Error: data byte must be in range 0..127
# Skipping File ceKteepohtB3zMhEeXAXmP.mid. Error: data byte must be in range 0..127
# Skipping File CRdFkMb7DQNKvoUsLxYTdy.mid. Error: running status without last_status
# Skipping File cYBmKe8j7TzaFjxnmsLEDh.mid. Error: running status without last_status
# Skipping File DEs8PcT7pGdidRhZd5zxxH.mid. Error: data byte must be in range 0..127
# Skipping File dRSAAkVMUoDHbrJ3qpzkP3.mid. Error: running status without last_status
# Skipping File e4hJLfF8zEAzBJmgm6EqL6.mid. Error: running status without last_status
# Skipping File e56co3SxXMULuDTQfRKNzg.mid. Error: running status without last_status
# Skipping File E9HMvWFa7Gti45mCEozPy5.mid. Error: data byte must be in range 0..127
# Skipping File EEuh5wDNtKBonQHwpa54J6.mid. Error: running status without last_status
# Skipping File eobzpaHn5M8YKtLXEc6GSE.mid. Error: running status without last_status
# Skipping File eofVcLpYH64ves6HNnMqse.mid. Error: running status without last_status
# Skipping File et5K5WgjGdndnvZoni39tS.mid. Error: running status without last_status
# Skipping File ethWgsKu5GL3CJzTRM4Xj6.mid. Error: running status without last_status
# Skipping File ewP4oVNwrDuiDdsc84WHZW.mid. Error: data byte must be in range 0..127
# Skipping File eWpQeubGcYgdXEoRDpWkcK.mid. Error: running status without last_status
# Skipping File f32vHjhGHb4PZPHr9knmgK.mid. Error: running status without last_status
# Skipping File FcyXnVQHYoeJLpyLU4bYW4.mid. Error: data byte must be in range 0..127
# Skipping File fg6AJQ56BScSMMmtVs8Xyx.mid. Error: running status without last_status
# Skipping File fmSffyrRtkJwsY7UBhNxXs.mid. Error: running status without last_status
# Skipping File FuErEHamfBWehF3DYWfJbf.mid. Error: running status without last_status
# Skipping File G6NsLb6YrsoN42xCdriBW2.mid. Error: running status without last_status
# Skipping File GJ3sHe9tYqTVXocCjrJM82.mid. Error: running status without last_status
# Skipping File GMc6aNuPdG6b4qey3vUrfp.mid. Error: running status without last_status
# Skipping File GRQeh7HwkUNDRiRWbXE4ph.mid. Error: running status without last_status
# Skipping File GWqym9reyweGSmCmBQ7LtX.mid. Error: data byte must be in range 0..127
# Skipping File h2ZUiwus9Ka4nGAYDQN98s.mid. Error: running status without last_status
# Skipping File h8rtxpqtNw2iffzC46hsjh.mid. Error: running status without last_status
# Skipping File hbResm8ANzLz3dGAb5FPdX.mid. Error: running status without last_status
# Skipping File hscrEAMDRF6gpRfw329RBv.mid. Error: running status without last_status
# Skipping File HsHW9Ksx3EH2QMTubD92UE.mid. Error: running status without last_status
# Skipping File icXy8RpTtZmPvq7ysb8gnU.mid. Error: running status without last_status
# Skipping File ih8ssmnj3sXFJFNbuESVqW.mid. Error: running status without last_status
# Skipping File iYkdf6akaA8LPrGdTEcZUj.mid. Error: running status without last_status
# Skipping File JfzUHKYccS6tNrF6eCyqTW.mid. Error: data byte must be in range 0..127
# Skipping File Jj5fuqBpMdJiK6eBTED4Fj.mid. Error: running status without last_status
# Skipping File jnfrMD7GaciacN8BmcjAaf.mid. Error: running status without last_status
# Skipping File jQxsVu7VXoNQpiUHDUy9Mm.mid. Error: running status without last_status
# Skipping File JShwgSJR4UAzrkBa8y8hWR.mid. Error: data byte must be in range 0..127
# Skipping File jSWmZh2QvwqPwCkSKaFctx.mid. Error: running status without last_status
# Skipping File JwHWRgbsCZ44TUE7Z8xso9.mid. Error: running status without last_status
# Skipping File JzBgSGPsiWkXJfVisB8e7t.mid. Error: running status without last_status
# Skipping File Jzu8LSuxCYpMJo7qYr26nr.mid. Error: running status without last_status
# Skipping File kxTgHSPtybTAUErcnHQDnn.mid. Error: running status without last_status
# Skipping File LqyFpHAdJvPVQ829YQkWti.mid. Error: running status without last_status
# Skipping File LsBA7KN98j7QxcJPq9MdkA.mid. Error: running status without last_status
# Skipping File LuGLk7wj6x8dPPhzbkUj3R.mid. Error: running status without last_status
# Skipping File m92bCCeZ3MkmigSWKG6fGH.mid. Error: list index out of range
# Skipping File MbCxmiMsZQG5yebT54yg6x.mid. Error: running status without last_status
# Skipping File mEZ7WsY8CwC5ceEchEHEvo.mid. Error: running status without last_status
# Skipping File MfgEkUw6Dexwb7rGUEVGYN.mid. Error: running status without last_status
# Skipping File mNyTsrfZGVJ7Gc4cTgyuEg.mid. Error: running status without last_status
# Skipping File moqof8ASixiBHyGPfBDiLX.mid. Error: running status without last_status
# Skipping File mT6ELtEFepabhXjMCn2TPd.mid. Error: running status without last_status
# Skipping File MwLVDgdW5fjh4YvjSrefTX.mid. Error: running status without last_status
# Skipping File mzxJ5ksQEGoVj5Q9w6VMJd.mid. Error: running status without last_status
# Skipping File N3FYjrgQJfkH3AoC42NnEv.mid. Error: running status without last_status
# Skipping File nejgiFuGG8qXYt3Au9TiMc.mid. Error: running status without last_status
# Skipping File nk3QoPpuraWc84shhYQj75.mid. Error: running status without last_status
# Skipping File NKcdxLiC9c4MEbYHmF3Y5S.mid. Error: data byte must be in range 0..127
# Skipping File nMnJa6ZRCRpCsJ83E4igCA.mid. Error: running status without last_status
# Skipping File Nu2Qu5JYyCHd6pxjdQkxAv.mid. Error: running status without last_status
# Skipping File NVp4GgQCi4NewZ6hprTZ3s.mid. Error: running status without last_status
# Skipping File NwUkowZp9aPd9uXvFtsxtW.mid. Error: running status without last_status
# Skipping File NYnhFN95bUykTXCuiKa5Tp.mid. Error: running status without last_status
# Skipping File oCBxXxr4VqhFH2bqw5UqHJ.mid. Error: running status without last_status
# Skipping File oHSaDCXRfwPWcWFuGKz44N.mid. Error: running status without last_status
# Skipping File oS3cFyh6MC8TQo4ahXvARV.mid. Error: running status without last_status
# Skipping File oSveJyEb4PAsK3rbJAbGkB.mid. Error: running status without last_status
# Skipping File PcEJiJU94vPEwpFxM7i2pP.mid. Error: float division by zero
# Skipping File Q8u3KeF8fhacjYALtN3gFA.mid. Error: running status without last_status
# Skipping File QdP3pixmQNXHfLNXnaxVJq.mid. Error: running status without last_status
# Skipping File QggJaJiTeJwrUMHyZZgKsK.mid. Error: data byte must be in range 0..127
# Skipping File QVoyzAo3d6LDem3RhQNouy.mid. Error: running status without last_status
# Skipping File R5zGn2uJ64h6Np3JqEewMS.mid. Error: running status without last_status
# Skipping File RqtYEUJHkaxARoZtGPNBXL.mid. Error: running status without last_status
# Skipping File St8LkNZBp6zbWFqdn2mCT9.mid. Error: MIDI file has a largest tick of 4295466857, it is likely corrupt
# Skipping File Uwy9DqKaYko2mRJEDk89jR.mid. Error: running status without last_status
# Skipping File UyGgMQHBRwyf2aHwcAaDun.mid. Error: running status without last_status
# Skipping File VDwRpoVafzkYwCRyV4UfGz.mid. Error: running status without last_status
# Skipping File VEwN33u9VYhtAxBTyeoiXu.mid. Error: running status without last_status
# Skipping File VtQ8uJDKjZagcobttRPNDe.mid. Error: running status without last_status
# Skipping File VWMFujaXg4ZheyuasgFWme.mid. Error: running status without last_status
# Skipping File WbVHDnffLbesM6bRCL2Uod.mid. Error: running status without last_status
# Skipping File WkwXkTqBXAyRhmk4pH725W.mid. Error: running status without last_status
# Skipping File Wse6mQUFAb4G58CZFcF2dL.mid. Error: data byte must be in range 0..127
# Skipping File Ww6wdoS3oCeuBKr45QURBM.mid. Error: Could not decode key with 3 flats and mode 255
# Skipping File X7J8etrH2sPy6AeYK6NwkG.mid. Error: data byte must be in range 0..127
# Skipping File XqLAqGo5jcN4u3BCzFmfZF.mid. Error: running status without last_status
# Skipping File YHg3JWEXifAHXAA7AP6bZ4.mid. Error: running status without last_status
# Skipping File YiXhLsjm5SAWnj2znvu6Ms.mid. Error: data byte must be in range 0..127
# Skipping File YrgybcLi2VPvSX3LK8eDiu.mid. Error: running status without last_status
# Skipping File YxVX9Lg4RxFMEKDj5dE27R.mid. Error: data byte must be in range 0..127
# Skipping File ZbTC5yjEyNcaoMvDUUyV8w.mid. Error: data byte must be in range 0..127
# Skipping File ZdvgPREMFLt4VNeHDXkDZ3.mid. Error: running status without last_status
# Skipping File ZhwXZwXr6ALfz8owjX2gMH.mid. Error: running status without last_status
#
# Finished
# Total number of errors: 123
