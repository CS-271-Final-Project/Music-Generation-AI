# %%
# Music processing
from pretty_midi import *
# Algorithms
from itertools import takewhile
# File management
import os
from glob import glob
from pathlib import Path
import csv

# %% [markdown]
# ## Settings

# %%
# Jazz music target and destination
corpus_path = r'C:\Users\alext\Desktop\School\2021 Spring\CS 271\Final Project\Feature Extraction\Classical\Classical Corpus (Solo Piano Only)'
export_path = r'C:\Users\alext\Desktop\School\2021 Spring\CS 271\Final Project\Feature Extraction\Classical\Classical Extracted Notes (Solo Piano Only)'

# Minimum number of notes per part
min_notes = 25
# Minimum number of chord phrases per part
min_chords = 1

# 0 = Treble, 1 = Bass
clef = 1

# %% [markdown]
# ## Export a Music File to a CSV File

# %%
def export_file(corpus_path, export_path, file_name):
    # Construct the full path of the music file
    file_path = os.path.join(corpus_path, file_name);
    # Construct the full path of the target csv file
    target_path = os.path.join(export_path, file_name[:-4] + '.csv');
    
    # If the csv already exists, skip this music file
    if os.path.exists(target_path):
        return
    
    # Parse the file and convert it into a stream object
    midi_data = pretty_midi.PrettyMIDI(file_path)
    
    # Get the desired clef
    inst = midi_data.instruments[clef]
    
    # Get the class of instrument
    inst_class = program_to_instrument_class(inst.program)

    # Check for keyboard instruments
    if inst_class == 'Piano' or inst_class == 'Organ':
        # Check if the part meets the minimum note requirement
        if len(inst.notes) >= min_notes:
            # Remove the extension of the music file name
            part_name = file_name[:-4]

            # Export the notes in the part to a csv
            export_part(corpus_path, export_path, inst.notes, part_name)

# %% [markdown]
# ## Export a Part to a CSV File

# %%
def export_part(corpus_path, export_path, part, part_name):
    # Extract the notes of the part
    notes = extract_notes(part)
    
    # If the part doesn't contain enough chords, don't export it
    if notes == None:
        return
    
    # Construct the full path of the target csv file
    csv_path = os.path.join(export_path, part_name + '.csv');
    
    # Write the features list to a csv file
    with open(csv_path, 'w', newline='') as csv_file:
        write = csv.writer(csv_file)
        write.writerows(notes)

# %% [markdown]
# ## Extract the Notes from a Part

# %%
def extract_notes(part):
    # An orderd list of phrases (notes and chords) in the song
    phrase_list = []
    # The phrase currently being processed
    phrase = []
    # The number of chords in the part
    num_chords = 0
    # The start time of the note currently being processed
    curr_time = part[0].start
    
    # Organize all notes into parts and add them to the part list
    for note in part:
        # If this note starts a the same time as the previous,
        # append it to the chord
        if note.start == curr_time:
            phrase.append(str(note.pitch))
        # If this note starts later than the previous one,
        # save the last phrase and construct a new one
        else:
            phrase_list.append(phrase)
            
            if len(phrase) > 1:
                num_chords += 1
            
            phrase = []
            phrase.append(str(note.pitch))
            curr_time = note.start
    
    # Add the last phrase
    phrase_list.append(phrase)
    
    if len(phrase) > 1:
        num_chords += 1
    
    # If the part doesn't contain enough chords, return nothing
    if num_chords < min_chords:
        return None
    
    return phrase_list

# %% [markdown]
# ## Preprocess the Music Corpus

# %%
print('Extracting...\n')

# Go to the corpus directory
os.chdir(corpus_path)

# Get a list of all music files in the corpus
music_files = glob('*.mid')

num_errors = 0

# Export the notes of each score as a csv file
for file_name in music_files:
    try:
        export_file(corpus_path, export_path, file_name)
    except Exception as err:
        print("Skipping File {0}. Error: {1}".format(file_name, err))
        num_errors += 1

print('\nFinished')
print('Total number of errors: ' + str(num_errors))
# Out:
# Extracting...
# C:\Users\alext\Desktop\Coding\Jupyter\env\DeepLearning\lib\site-packages\pretty_midi\pretty_midi.py:97: RuntimeWarning: Tempo, Key or Time signature change events found on non-zero tracks.  This is not a valid type 0 or type 1 MIDI file.  Tempo, Key or Time Signature may be wrong.
#   warnings.warn(
# Skipping File 2mvgmYeZUHTpPtHucAF5ov.mid. Error: list index out of range
# Skipping File 2n2nTLX3pqdQopUgXoDif3.mid. Error: list index out of range
# Skipping File 2TRSYfaH5ZyxadorDdRMz9.mid. Error: list index out of range
# Skipping File 2wYGnCjbfdLLeBV9P3PyuL.mid. Error: list index out of range
# Skipping File 2YdxRbpcpmht3fKbBsnwKY.mid. Error: list index out of range
# Skipping File 3Jc2jW4gBtpHoWPpwJjLJ3.mid. Error: list index out of range
# Skipping File 42waeofCadEwSvTGQo7VqP.mid. Error: list index out of range
# Skipping File 45wssfpzEkcb4s42qBLACv.mid. Error: list index out of range
# Skipping File 4atYcxiMCB9xXb4CnpGRMt.mid. Error: list index out of range
# Skipping File 4bJUa7Nd5um6yBawkN9bCo.mid. Error: list index out of range
# Skipping File 4CaYHmGvAz9C3v8kfZjfpq.mid. Error: list index out of range
# Skipping File 4KsAPdSCRWJntAzqqRMQWP.mid. Error: list index out of range
# Skipping File 4tR8e7CgDr2VATPd5vkcZG.mid. Error: list index out of range
# Skipping File 54HwWFozfhVXYc8BMhxDi7.mid. Error: list index out of range
# Skipping File 5j8zG4qCXvmrFJxeUjyWqM.mid. Error: list index out of range
# Skipping File 5LeWhSNQLyPHbGjyCPtkU8.mid. Error: list index out of range
# Skipping File 5WjL9GbBXjgYG7kmEQZuDS.mid. Error: list index out of range
# Skipping File 6CEqV5Gr6cEHkdPhYgrZQM.mid. Error: list index out of range
# Skipping File 6m6nVE2sZJUAtrXfaXW9qf.mid. Error: list index out of range
# Skipping File 73kusjCdZhRWC49jnHHcNX.mid. Error: list index out of range
# Skipping File 7eXkDwvfiZo2KdJ6i9isWd.mid. Error: list index out of range
# Skipping File 7tRvB6NtEAzLn9Jr2m58Wh.mid. Error: list index out of range
# Skipping File 87abkTMsFLJhNrfLxguD3K.mid. Error: float division by zero
# Skipping File 8EE7fmx4qEgsdKfg2eTheK.mid. Error: list index out of range
# Skipping File 8eiHXmJbzJkUZwZ2mEBZDs.mid. Error: list index out of range
# Skipping File 8oLscKLD4qpDyAUmWmtwsD.mid. Error: list index out of range
# Skipping File 8YfJ5P2mWcQZbg2TYHLyDY.mid. Error: list index out of range
# Skipping File 8YrRyRFWvg65yEcEXBHLZ5.mid. Error: list index out of range
# Skipping File 99yeQytLMWiGGyHr8MyWb5.mid. Error: list index out of range
# Skipping File 9agcz3GQedQKcFrAXcwaVZ.mid. Error: list index out of range
# Skipping File 9NqmZy6AnTNFK9afrrMpUY.mid. Error: list index out of range
# Skipping File 9ZhdRJDanCyXyVhFNHCxwy.mid. Error: list index out of range
# Skipping File aa5YmAe2hEQdU5gTXKiqh3.mid. Error: list index out of range
# Skipping File aaT6mwpFhpNXqhGSZ48kRA.mid. Error: list index out of range
# Skipping File ab9tSLasv6V8QuEpd5zjPH.mid. Error: list index out of range
# Skipping File ADR2wbkYx4Zu2HwyrdH436.mid. Error: list index out of range
# Skipping File aF6kaohU27yU3BCrM22g27.mid. Error: list index out of range
# Skipping File aLpy8R4w7qbBYDAvrMzSsd.mid. Error: list index out of range
# Skipping File aT4LD8Xivf4m9sTx3jKmyK.mid. Error: list index out of range
# Skipping File atN4KoYPFW6YiZueGDqk4S.mid. Error: list index out of range
# Skipping File aY9csfKLcCU5Jax2JWnUyg.mid. Error: list index out of range
# Skipping File B8b5inHuZ463qZsKHnHz3m.mid. Error: list index out of range
# Skipping File BFBQK3bwcGzHNqCisT3YNt.mid. Error: list index out of range
# Skipping File BfvzGwQqTo8cnDuo762sLA.mid. Error: list index out of range
# Skipping File BGLFDv2vTHvgYriPjHLA3V.mid. Error: list index out of range
# Skipping File bHYBjQ8XBtxb8Gw95e4mSc.mid. Error: list index out of range
# Skipping File BJuLKeegteNHSypNsBbQXq.mid. Error: list index out of range
# Skipping File BTK7A6suFiBfq9pFxrSv8s.mid. Error: list index out of range
# Skipping File BU3Zgikmcpe6GwRK4Uk2iZ.mid. Error: list index out of range
# Skipping File bYbdmKjN6ZKoUhJrioDNZm.mid. Error: list index out of range
# Skipping File c5titBidNJr6yyiLbBdCV7.mid. Error: list index out of range
# Skipping File c9TJcUPcEENxdi5FGohxPe.mid. Error: list index out of range
# Skipping File cawrb5dWbTRHuskF35zrJi.mid. Error: list index out of range
# Skipping File ccMga3shHmbGTneE8kpCne.mid. Error: list index out of range
# Skipping File CfQX53vmTVs2BsqtKtbwQK.mid. Error: list index out of range
# Skipping File CNjrbmqqctNFGsyHkoK2hz.mid. Error: list index out of range
# Skipping File coPYXYcnXS4Fya8c5xPnFp.mid. Error: list index out of range
# Skipping File cS6vYEDYJteaGYog4pZLuV.mid. Error: list index out of range
# Skipping File ctSbhJHVdry3zUQckMCAcY.mid. Error: list index out of range
# Skipping File cwvvVUsUYKd6idBNUbTkjs.mid. Error: list index out of range
# Skipping File cZzrJKqBWuwZG6iEHcUko3.mid. Error: list index out of range
# Skipping File d4BCTSh5fs87k5gpx6uWpE.mid. Error: list index out of range
# Skipping File D4sFgKuyNg7oRQrJekGHFj.mid. Error: list index out of range
# Skipping File dbCGMkgf7HDRy45rvr6mG7.mid. Error: list index out of range
# Skipping File DCZ7gQpFeiWHnbom2kYkiB.mid. Error: list index out of range
# Skipping File dDfBuNWw3hm65NCqW5uaiX.mid. Error: list index out of range
# Skipping File dGDpr9J26JRwBBrEFRhsAk.mid. Error: list index out of range
# Skipping File DjBLXVzK6MtVUauzoRYM66.mid. Error: list index out of range
# Skipping File dkrmfgimhstNiSvKk7RKqJ.mid. Error: list index out of range
# Skipping File DN2pJtQrr8W7p2MjkiJeMf.mid. Error: list index out of range
# Skipping File dZGudLVTQUenNx7Dgsfkhh.mid. Error: list index out of range
# Skipping File e8QGZFQ7VJLxRJaRNtfoLr.mid. Error: list index out of range
# Skipping File Ecrf8AVLJWL9QRFtHHoNPT.mid. Error: list index out of range
# Skipping File Egb5wevckLQqfea72HSKEw.mid. Error: list index out of range
# Skipping File EkQvP24xgBHoxjtzKXwdRQ.mid. Error: list index out of range
# Skipping File epresP7Us9kkUzWYC6Pfj2.mid. Error: list index out of range
# Skipping File eWrLT4UtJyrQ394wzPyT3r.mid. Error: list index out of range
# Skipping File F4ryYEinD25bzG9XJzcSZg.mid. Error: list index out of range
# Skipping File FA7NGCcwGJM8XKTpHDez9Q.mid. Error: list index out of range
# Skipping File FFNiWwghEHDFFSijqRDpHu.mid. Error: list index out of range
# Skipping File fsB9qtHxEc47ABxf8vr33q.mid. Error: list index out of range
# Skipping File ftg5FvKwif4AnMUPNDLFuz.mid. Error: list index out of range
# Skipping File FWs3MUJuqVYRbdw9ZktThR.mid. Error: list index out of range
# Skipping File G8dCG6UfeA7uSYwv4NRPSk.mid. Error: list index out of range
# Skipping File GBopz7JGjsCwdxyUYw228E.mid. Error: list index out of range
# Skipping File gbrMRp7TYJkpuq6zxF5DoH.mid. Error: list index out of range
# Skipping File gBsqytuw9Dw4Be5UaxDVa5.mid. Error: list index out of range
# Skipping File gc66bhazL53MD9gt7HkhBB.mid. Error: list index out of range
# Skipping File gpaaJB9QPQe8HmNCcHKXxj.mid. Error: list index out of range
# Skipping File GR8onMbtGMMaHfxotSXYsm.mid. Error: list index out of range
# Skipping File GuTxLU2Z4qrX9m49a6ie3r.mid. Error: list index out of range
# Skipping File GwbebecEKr7YRKMdpbiM6r.mid. Error: list index out of range
# Skipping File gWBPiQMxdVyuEvxtsZBqQW.mid. Error: list index out of range
# Skipping File H3jwFNyLtyGxBcZi9yDYdJ.mid. Error: list index out of range
# Skipping File h6PdCrEGJw9AwDQANfCMCV.mid. Error: list index out of range
# Skipping File h9UetykeBFBZkrhKPxFMdU.mid. Error: list index out of range
# Skipping File Hd4QfbJQSVDmcZMHFrCwpc.mid. Error: list index out of range
# Skipping File hDpKFkG6vZSoQE9LMo8yeP.mid. Error: list index out of range
# Skipping File hmjE2fnsZSiudZaKFCrgLY.mid. Error: list index out of range
# Skipping File HNjKXSgc9Qeoqi5hqdhTz4.mid. Error: list index out of range
# Skipping File HxruY4rdUMJnfi7ca3MfwR.mid. Error: list index out of range
# Skipping File i3KWsK9eTY7PKbsTooXRkv.mid. Error: list index out of range
# Skipping File ibZBU2PQnPSTpxHZ5M6E3p.mid. Error: list index out of range
# Skipping File idBSweZBdc7oC4JQEVpFfH.mid. Error: list index out of range
# Skipping File ierykSHXz6CU9K42KKyJzE.mid. Error: list index out of range
# Skipping File iSjtMKtP6Ko9T6UQc9Ak8i.mid. Error: MIDI file has a largest tick of 4295466857, it is likely corrupt
# Skipping File iv5UFfxSpDk5xd59c3jHt8.mid. Error: list index out of range
# Skipping File iyHefLK786YHGUyP2PRDA6.mid. Error: list index out of range
# Skipping File j6M3mGw7NyPsBauNVw3P7y.mid. Error: list index out of range
# Skipping File J9bxqV78cxiEPJsN8kA5XW.mid. Error: list index out of range
# Skipping File jDvJtp3Vc8RNZYBncpfSBz.mid. Error: list index out of range
# Skipping File jf4vJXLzMnkNAhpAtjcQWb.mid. Error: list index out of range
# Skipping File jfkBDTsp8NRDQUqPZ2F35P.mid. Error: list index out of range
# Skipping File jgf4QzTESdwPeZhQKhDC7e.mid. Error: list index out of range
# Skipping File JHvEZEeCGQHwP3RAzyTUr8.mid. Error: list index out of range
# Skipping File JKMri9rAD97Ncj8yussoso.mid. Error: list index out of range
# Skipping File JmhqaLZxcFrcQYnzefGbpG.mid. Error: list index out of range
# Skipping File jMtU3RFQ6J5u4QLvMTLjB8.mid. Error: list index out of range
# Skipping File jP3izsRtQyGrhe96zKTsHL.mid. Error: list index out of range
# Skipping File jQkR8bL4MjUpe2ofzbZAtE.mid. Error: list index out of range
# Skipping File JspzSk8chnrUHV8id28AbP.mid. Error: list index out of range
# Skipping File jZTQ992CQTgLQtvC8dUUUL.mid. Error: list index out of range
# Skipping File k3B8gMJpVmLShkxUvsLCkq.mid. Error: list index out of range
# Skipping File K7muSQFBf9XAF4yjS6A2fE.mid. Error: MIDI file has a largest tick of 4295154736, it is likely corrupt
# Skipping File kBrvfrxQRmmzituH4trwDR.mid. Error: list index out of range
# Skipping File KPNgUpnDxBDdRDNTtB2Ytf.mid. Error: list index out of range
# Skipping File Kxma7zm2ouu8WqfB8me6Jb.mid. Error: list index out of range
# Skipping File KxTw6HS3H7ZtsCkXTvvfQu.mid. Error: list index out of range
# Skipping File LBpbzDFXBm9EZj4AJARS6f.mid. Error: list index out of range
# Skipping File LByJG7QXUDL43wXUVEYizv.mid. Error: list index out of range
# Skipping File Lyjc6BrsidAbu2tRHk2HUV.mid. Error: list index out of range
# Skipping File LzHMx7jUKPvWPCp4442Agm.mid. Error: list index out of range
# Skipping File m2yR2DpcNMfBFs2ZV9eY8f.mid. Error: list index out of range
# Skipping File M3CQSnb4Y8EbvbM9iFEUbz.mid. Error: list index out of range
# Skipping File M3JUpCQrKmwfDLfeuqDPcq.mid. Error: list index out of range
# Skipping File M7Ga3jqeHhFxmaGq6pYDjs.mid. Error: list index out of range
# Skipping File MBJmjz7pUS4FoQt7mfH6yt.mid. Error: list index out of range
# Skipping File MFGeQMU7Jx8ZnFttQX78oT.mid. Error: list index out of range
# Skipping File mL2nQrsAufxhvN85SNxyEr.mid. Error: list index out of range
# Skipping File MqpHgDetwbRBvjEZenoACJ.mid. Error: list index out of range
# Skipping File N9vRbLPs7JpXyMdD6ygAhM.mid. Error: list index out of range
# Skipping File nAjNy6f5FKUXDuJcB49neu.mid. Error: list index out of range
# Skipping File nbQTswCLyQHXPHDVvZft5j.mid. Error: list index out of range
# Skipping File NG3qnQwQn6suHUsCWsNmN7.mid. Error: list index out of range
# Skipping File NHabsBxDg6pQ4YTN3kheCJ.mid. Error: list index out of range
# Skipping File NsDnx4ZEML6NPwNty2x3Eq.mid. Error: list index out of range
# Skipping File Nu52Q42bDvHWEhcJNhMojr.mid. Error: list index out of range
# Skipping File NxamcwPauUWqvugNDFNdDk.mid. Error: list index out of range
# Skipping File nya9Kh8sMf95JFxtTCzAex.mid. Error: list index out of range
# Skipping File NZPR3tPLQfSLMbNqTLEP4o.mid. Error: list index out of range
# Skipping File o6zeHghi6j8ReWSjX7fv6k.mid. Error: list index out of range
# Skipping File PbWTqzkvohw3NprAjst2SK.mid. Error: list index out of range
# Skipping File PE8CSTipXThRMc7ZuuKw54.mid. Error: list index out of range
# Skipping File PM45Z6wKzK2NDqSbg6sc8J.mid. Error: list index out of range
# Skipping File PQiRdNHnpSMnDSoUQZNkqv.mid. Error: list index out of range
# Skipping File QmE9K5T5TKJAZCiTWE5Mde.mid. Error: list index out of range
# Skipping File Qu24SzFTW8fDpLDfHdmRxZ.mid. Error: list index out of range
# Skipping File RGKcnWmsqogQpzebVvmzsj.mid. Error: list index out of range
# Skipping File RsPHArzK2bFnDrg4p4x9vy.mid. Error: list index out of range
# Skipping File Sctjpk5VKkin9RVZ9BXbXw.mid. Error: list index out of range
# Skipping File TG36KwywSPxRjqMN9UaGD4.mid. Error: list index out of range
# Skipping File TPxphN58YScouSzhGAEhRk.mid. Error: list index out of range
# Skipping File UcRB9KopeqqSwMTwkodapv.mid. Error: list index out of range
# Skipping File UP6A4ZzWuGeTrFKuNJkfDp.mid. Error: list index out of range
# Skipping File Ut79RpitS6VN2EpiffnxKt.mid. Error: list index out of range
# Skipping File VUbqZiYsWxgDknpKPgexch.mid. Error: list index out of range
# Skipping File WBcfyhX8ysQ3frFbdtvz24.mid. Error: list index out of range
# Skipping File WDq9vK7udmnwwqn5V4JQPi.mid. Error: list index out of range
# Skipping File WgGVAcZP584XxsTkGXJp5h.mid. Error: list index out of range
# Skipping File Wi8Q6Hef6wRr95Zo2cFx7h.mid. Error: list index out of range
# Skipping File WQSh6UeJ9Zneh78fkBdXes.mid. Error: list index out of range
# Skipping File WQVT44VkXodEdyVs7VeNsv.mid. Error: list index out of range
# Skipping File WU8fDmDTNPUUKn7zn5Z2Yn.mid. Error: list index out of range
# Skipping File WvtP4SYF7tfrTDUCuF6qrE.mid. Error: list index out of range
# Skipping File WZThQQTHKFduRrvFM6QdMX.mid. Error: list index out of range
# Skipping File XAPmjEA64UCtmHLnCqWKN2.mid. Error: list index out of range
# Skipping File XEtk63V5cGgwLe87GoYz3E.mid. Error: list index out of range
# Skipping File XgxN8PiuyJ4wUrVDi4xrBt.mid. Error: list index out of range
# Skipping File YbF9nkBQGSSPpXyHbeMifq.mid. Error: list index out of range
# Skipping File Z5Xi7hc6Qui3apVbUj8yHu.mid. Error: list index out of range
#
# Finished
# Total number of errors: 180
